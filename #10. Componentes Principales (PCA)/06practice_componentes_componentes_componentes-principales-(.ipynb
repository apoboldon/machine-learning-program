# %% [markdown]
# <font size="+5">#06 | Componentes Principales (PCA)</font>

# %% [markdown]
# - Subscribe to my [Blog ↗](https://blog.pythonassembly.com/)
# - Let's keep in touch on [LinkedIn ↗](www.linkedin.com/in/jsulopz) 😄

# %% [markdown]
# # Discipline to Search Solutions in Google

# %% [markdown]
# > Apply the following steps when **looking for solutions in Google**:
# >
# > 1. **Necesity**: How to load an Excel in Python?
# > 2. **Search in Google**: by keywords
# >   - `load excel python`
# >   - ~~how to load excel in python~~
# > 3. **Solution**: What's the `function()` that loads an Excel in Python?
# >   - A Function to Programming is what the Atom to Phisics.
# >   - Every time you want to do something in programming
# >   - **You will need a `function()`** to make it
# >   - Theferore, you must **detect parenthesis `()`**
# >   - Out of all the words that you see in a website
# >   - Because they indicate the presence of a `function()`.

# %% [markdown]
# # Load the Data

# %% [markdown]
# > - Simply execute the following lines of code to load the data
# > - This dataset contains **statistics** (columns)
# > - About **Car Models** (rows)

# %%
import seaborn as sns

df = sns.load_dataset(name='mpg', index_col='name')
df.sample(10)
# Out:
#                        mpg  cylinders  displacement  horsepower  weight  \
# name
# buick lesabre custom  13.0          8         350.0       155.0    4502
# chevrolet vega        25.0          4         140.0        75.0    2542
# toyota carina         20.0          4          97.0        88.0    2279
# pontiac ventura sj    18.5          6         250.0       110.0    3645
# triumph tr7 coupe     35.0          4         122.0        88.0    2500
# pontiac phoenix       27.0          4         151.0        90.0    2735
# datsun 210            40.8          4          85.0        65.0    2110
# fiat 131              28.0          4         107.0        86.0    2464
# bmw 2002              26.0          4         121.0       113.0    2234
# datsun 310            37.2          4          86.0        65.0    2019
#
#                       acceleration  model_year  origin
# name
# buick lesabre custom          13.5          72     usa
# chevrolet vega                17.0          74     usa
# toyota carina                 19.0          73   japan
# pontiac ventura sj            16.2          76     usa
# triumph tr7 coupe             15.1          80  europe
# pontiac phoenix               18.0          82     usa
# datsun 210                    19.2          80   japan
# fiat 131                      15.5          76  europe
# bmw 2002                      12.5          70  europe
# datsun 310                    16.4          80   japan

# %%
import pandas as pd
df=pd.get_dummies(data=df) # asignamos un valor numérico de 0 o 1 para la columna de origin, con valores no numéricos.
df
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0       130.0    3504
# buick skylark 320          15.0          8         350.0       165.0    3693
# plymouth satellite         18.0          8         318.0       150.0    3436
# amc rebel sst              16.0          8         304.0       150.0    3433
# ford torino                17.0          8         302.0       140.0    3449
# ...                         ...        ...           ...         ...     ...
# ford mustang gl            27.0          4         140.0        86.0    2790
# vw pickup                  44.0          4          97.0        52.0    2130
# dodge rampage              32.0          4         135.0        84.0    2295
# ford ranger                28.0          4         120.0        79.0    2625
# chevy s-10                 31.0          4         119.0        82.0    2720
#
#                            acceleration  model_year  origin_europe  \
# name
# chevrolet chevelle malibu          12.0          70              0
# buick skylark 320                  11.5          70              0
# plymouth satellite                 11.0          70              0
# amc rebel sst                      12.0          70              0
# ford torino                        10.5          70              0
# ...                                 ...         ...            ...
# ford mustang gl                    15.6          82              0
# vw pickup                          24.6          82              1
# dodge rampage                      11.6          82              0
# ford ranger                        18.6          82              0
# chevy s-10                         19.4          82              0
#
#                            origin_japan  origin_usa
# name
# chevrolet chevelle malibu             0           1
# buick skylark 320                     0           1
# plymouth satellite                    0           1
# amc rebel sst                         0           1
# ford torino                           0           1
# ...                                 ...         ...
# ford mustang gl                       0           1
# vw pickup                             0           0
# dodge rampage                         0           1
# ford ranger                           0           1
# chevy s-10                            0           1
#
# [398 rows x 10 columns]

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# - All variables need to be **comparables**.
# - It is not the same to increase 1kg of weight, than 1m of height.
# - We will use `StandardScaler()`.

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
scaler.fit(df)
# Out:
# StandardScaler()

# %%
datanorm=scaler.transform(df) # normalizamos los datos
datanorm
# Out:
# array([[-0.7064387 ,  1.49819126,  1.0906037 , ..., -0.46196822,
#         -0.49764335,  0.77355903],
#        [-1.09075062,  1.49819126,  1.5035143 , ..., -0.46196822,
#         -0.49764335,  0.77355903],
#        [-0.7064387 ,  1.49819126,  1.19623199, ..., -0.46196822,
#         -0.49764335,  0.77355903],
#        ...,
#        [ 1.08701694, -0.85632057, -0.56103873, ..., -0.46196822,
#         -0.49764335,  0.77355903],
#        [ 0.57460104, -0.85632057, -0.70507731, ..., -0.46196822,
#         -0.49764335,  0.77355903],
#        [ 0.95891297, -0.85632057, -0.71467988, ..., -0.46196822,
#         -0.49764335,  0.77355903]])

# %%
dfnorm=pd.DataFrame(data=datanorm, columns=df.columns, index= df.index) # pasamos los datos normalizados a un dataframe.
dfnorm
# Out:
#                                 mpg  cylinders  displacement  horsepower  \
# name
# chevrolet chevelle malibu -0.706439   1.498191      1.090604    0.664133
# buick skylark 320         -1.090751   1.498191      1.503514    1.574594
# plymouth satellite        -0.706439   1.498191      1.196232    1.184397
# amc rebel sst             -0.962647   1.498191      1.061796    1.184397
# ford torino               -0.834543   1.498191      1.042591    0.924265
# ...                             ...        ...           ...         ...
# ford mustang gl            0.446497  -0.856321     -0.513026   -0.480448
# vw pickup                  2.624265  -0.856321     -0.925936   -1.364896
# dodge rampage              1.087017  -0.856321     -0.561039   -0.532474
# ford ranger                0.574601  -0.856321     -0.705077   -0.662540
# chevy s-10                 0.958913  -0.856321     -0.714680   -0.584501
#
#                              weight  acceleration  model_year  origin_europe  \
# name
# chevrolet chevelle malibu  0.630870     -1.295498   -1.627426      -0.461968
# buick skylark 320          0.854333     -1.477038   -1.627426      -0.461968
# plymouth satellite         0.550470     -1.658577   -1.627426      -0.461968
# amc rebel sst              0.546923     -1.295498   -1.627426      -0.461968
# ford torino                0.565841     -1.840117   -1.627426      -0.461968
# ...                             ...           ...         ...            ...
# ford mustang gl           -0.213324      0.011586    1.621983      -0.461968
# vw pickup                 -0.993671      3.279296    1.621983       2.164651
# dodge rampage             -0.798585     -1.440730    1.621983      -0.461968
# ford ranger               -0.408411      1.100822    1.621983      -0.461968
# chevy s-10                -0.296088      1.391285    1.621983      -0.461968
#
#                            origin_japan  origin_usa
# name
# chevrolet chevelle malibu     -0.497643    0.773559
# buick skylark 320             -0.497643    0.773559
# plymouth satellite            -0.497643    0.773559
# amc rebel sst                 -0.497643    0.773559
# ford torino                   -0.497643    0.773559
# ...                                 ...         ...
# ford mustang gl               -0.497643    0.773559
# vw pickup                     -0.497643   -1.292726
# dodge rampage                 -0.497643    0.773559
# ford ranger                   -0.497643    0.773559
# chevy s-10                    -0.497643    0.773559
#
# [398 rows x 10 columns]

# %% [markdown]
# # `KMeans()` Model in Python

# %% [markdown]
# ## Code Thinking
#
# > Which function computes the Model?
# > - `fit()`
# >
# > How could can you **import the function in Python**?

# %%
from sklearn.cluster import KMeans
model= KMeans(n_clusters=4)

# %%
dfnorm=dfnorm.dropna()# eliminamos los valores NaN
dfnorm
# Out:
#                                 mpg  cylinders  displacement  horsepower  \
# name
# chevrolet chevelle malibu -0.706439   1.498191      1.090604    0.664133
# buick skylark 320         -1.090751   1.498191      1.503514    1.574594
# plymouth satellite        -0.706439   1.498191      1.196232    1.184397
# amc rebel sst             -0.962647   1.498191      1.061796    1.184397
# ford torino               -0.834543   1.498191      1.042591    0.924265
# ...                             ...        ...           ...         ...
# ford mustang gl            0.446497  -0.856321     -0.513026   -0.480448
# vw pickup                  2.624265  -0.856321     -0.925936   -1.364896
# dodge rampage              1.087017  -0.856321     -0.561039   -0.532474
# ford ranger                0.574601  -0.856321     -0.705077   -0.662540
# chevy s-10                 0.958913  -0.856321     -0.714680   -0.584501
#
#                              weight  acceleration  model_year  origin_europe  \
# name
# chevrolet chevelle malibu  0.630870     -1.295498   -1.627426      -0.461968
# buick skylark 320          0.854333     -1.477038   -1.627426      -0.461968
# plymouth satellite         0.550470     -1.658577   -1.627426      -0.461968
# amc rebel sst              0.546923     -1.295498   -1.627426      -0.461968
# ford torino                0.565841     -1.840117   -1.627426      -0.461968
# ...                             ...           ...         ...            ...
# ford mustang gl           -0.213324      0.011586    1.621983      -0.461968
# vw pickup                 -0.993671      3.279296    1.621983       2.164651
# dodge rampage             -0.798585     -1.440730    1.621983      -0.461968
# ford ranger               -0.408411      1.100822    1.621983      -0.461968
# chevy s-10                -0.296088      1.391285    1.621983      -0.461968
#
#                            origin_japan  origin_usa
# name
# chevrolet chevelle malibu     -0.497643    0.773559
# buick skylark 320             -0.497643    0.773559
# plymouth satellite            -0.497643    0.773559
# amc rebel sst                 -0.497643    0.773559
# ford torino                   -0.497643    0.773559
# ...                                 ...         ...
# ford mustang gl               -0.497643    0.773559
# vw pickup                     -0.497643   -1.292726
# dodge rampage                 -0.497643    0.773559
# ford ranger                   -0.497643    0.773559
# chevy s-10                    -0.497643    0.773559
#
# [392 rows x 10 columns]

# %%
model.fit(dfnorm)
# Out:
# KMeans(n_clusters=4)

# %% [markdown]
# ## Get the `cluster` for all USA States

# %% [markdown]
# > - `model.` + `↹`

# %%
grupos= model.predict(dfnorm)

# %% [markdown]
# > - Create a `dfsel` DataFrame
# > - That contains the **columns you used for the model**

# %%
dfsel=df.copy()
dfsel=dfsel.dropna()

# %% [markdown]
# > - Add a **new column**
# > - That **contains the `cluster` prediction** for every USA State

# %%
dfsel['cluster'] = grupos
dfsel.head()
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0       130.0    3504
# buick skylark 320          15.0          8         350.0       165.0    3693
# plymouth satellite         18.0          8         318.0       150.0    3436
# amc rebel sst              16.0          8         304.0       150.0    3433
# ford torino                17.0          8         302.0       140.0    3449
#
#                            acceleration  model_year  origin_europe  \
# name
# chevrolet chevelle malibu          12.0          70              0
# buick skylark 320                  11.5          70              0
# plymouth satellite                 11.0          70              0
# amc rebel sst                      12.0          70              0
# ford torino                        10.5          70              0
#
#                            origin_japan  origin_usa  cluster
# name
# chevrolet chevelle malibu             0           1        1
# buick skylark 320                     0           1        1
# plymouth satellite                    0           1        1
# amc rebel sst                         0           1        1
# ford torino                           0           1        1

# %% [markdown]
# ## Model Visualization

# %% [markdown]
# > - You may `hue=` the points with the `cluster` column

# %%
sns.scatterplot(data=dfsel, x='mpg', y='horsepower', hue= 'cluster', palette='Set2');

# %% [markdown]
# ## Model Interpretation

# %% [markdown]
# > - Does the visualization makes sense?
# > - The points are mixed between the groups, why?
# > - We are **just representing 2 variables**
# > - And the model was **fitted with 7 variables**

# %% [markdown]
# # Grouping Variables with `PCA()`

# %%
# %%HTML
#
# <iframe width="560" height="315" src="https://www.youtube.com/embed/HMOI_lkzW08" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/HMOI_lkzW08" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# ## Transform Data to Components

# %% [markdown]
# > - `PCA()` is another technique used to transform data.
# > How has the data been manipulated so far?
# > 1. Original Data `df`
# > 2. Normalized Data `dfnorm`
# > 3. Principal Components Data `dfpca` (now)

# %%
from sklearn.decomposition import PCA
pca=PCA()

# %%
df=df.dropna()
pca.fit(df)
# Out:
# PCA()

# %%
pd.DataFrame(pca.components_.T, index= df.columns)
# Out:
#                       0         1         2         3         4         5  \
# mpg           -0.007596 -0.017578 -0.041937  0.830901  0.550465 -0.056315
# cylinders      0.001793  0.013322 -0.007282 -0.004331 -0.009365 -0.015326
# displacement   0.114338  0.945570 -0.303894  0.009114 -0.003430  0.010701
# horsepower     0.038966  0.298330  0.947566  0.063593 -0.005455  0.086278
# weight         0.992645 -0.120866 -0.002660  0.003539  0.003921 -0.003528
# acceleration  -0.001353 -0.034830 -0.076886 -0.020876  0.125499  0.988141
# model_year    -0.001337 -0.023949 -0.044133  0.552027 -0.823504  0.111987
# origin_europe -0.000131 -0.002488  0.002867 -0.007159  0.032827 -0.004094
# origin_japan  -0.000210 -0.000379  0.004748  0.013535  0.009250 -0.002055
# origin_usa     0.000341  0.002867 -0.007615 -0.006376 -0.042078  0.006149
#
#                       6         7         8             9
# mpg            0.000420 -0.010027  0.034555  1.982107e-17
# cylinders      0.972523 -0.158435  0.168886 -1.596957e-16
# displacement  -0.013339  0.002286 -0.008933  2.787495e-18
# horsepower     0.002492 -0.004737  0.007272 -6.165194e-18
# weight        -0.000201  0.000240  0.000252  1.578020e-19
# acceleration   0.016179 -0.001163  0.001287 -2.712922e-17
# model_year     0.001491 -0.013899 -0.042972 -1.997770e-17
# origin_europe -0.007421 -0.616585 -0.534111  5.773503e-01
# origin_japan   0.167522  0.757909 -0.252748  5.773503e-01
# origin_usa    -0.160101 -0.141323  0.786859  5.773503e-01

# %%
pca.fit(dfnorm)
# Out:
# PCA()

# %%
pd.DataFrame(pca.components_.T, columns= df.columns)
# Out:
#         mpg  cylinders  displacement  horsepower    weight  acceleration  \
# 0 -0.367106  -0.150109     -0.054341   -0.259149 -0.147167      0.747806
# 1  0.387568  -0.045398      0.020061   -0.105908  0.252445      0.479917
# 2  0.402415  -0.041913      0.014231   -0.103237  0.178485      0.300361
# 3  0.379338   0.005149      0.234369   -0.203496  0.056066     -0.070476
# 4  0.385829   0.007985     -0.038550   -0.110274  0.398785     -0.120822
# 5 -0.246830   0.057556     -0.444529    0.440393  0.661602      0.100407
# 6 -0.191344  -0.400459     -0.363659   -0.705053  0.223106     -0.298608
# 7 -0.159440   0.748044      0.035360   -0.348446  0.137020      0.015211
# 8 -0.214527  -0.450855      0.588295    0.123833  0.298530     -0.031693
# 9  0.302233  -0.216884     -0.512671    0.172053 -0.353829      0.014154
#
#    model_year  origin_europe  origin_japan    origin_usa
# 0    0.370230      -0.195897     -0.127560  2.505879e-16
# 1   -0.544162       0.309366     -0.387612  3.832174e-16
# 2    0.000420      -0.116868      0.830490 -2.753318e-16
# 3    0.673184       0.531831     -0.124922  1.810120e-16
# 4    0.213058      -0.708413     -0.341403 -8.145988e-17
# 5    0.212751       0.223007      0.037640  1.734009e-17
# 6   -0.114799       0.129361      0.069403  4.717652e-17
# 7   -0.048405       0.015417      0.038333  5.189293e-01
# 8   -0.043995      -0.027431      0.029974  5.436647e-01
# 9    0.074338       0.010480     -0.054859  6.596523e-01

# %%
datospca= pca.transform(dfnorm)
datospca
# Out:
# array([[ 2.80239667e+00,  2.93560431e-01,  6.64603143e-01, ...,
#         -9.82760409e-02, -1.21285137e-01, -5.64109217e-17],
#        [ 3.58604206e+00,  3.29966206e-01,  9.76832325e-01, ...,
#          2.14176158e-01,  7.37946993e-02, -5.64109217e-17],
#        [ 3.10085732e+00,  2.70272668e-01,  9.52538529e-01, ...,
#          1.42058283e-01, -8.47719564e-02,  5.46113808e-17],
#        ...,
#        [-1.02452048e+00, -1.12672776e+00, -8.46054489e-01, ...,
#         -2.20777518e-01,  4.84612695e-02,  5.46113808e-17],
#        [-1.42050248e+00, -8.95045650e-01, -1.99557710e+00, ...,
#          1.17644791e-01, -2.70919434e-02, -5.64109217e-17],
#        [-1.56420411e+00, -9.34315319e-01, -2.13175694e+00, ...,
#          7.01897260e-02, -1.21252572e-01,  5.46113808e-17]])

# %%
df.head()
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0       130.0    3504
# buick skylark 320          15.0          8         350.0       165.0    3693
# plymouth satellite         18.0          8         318.0       150.0    3436
# amc rebel sst              16.0          8         304.0       150.0    3433
# ford torino                17.0          8         302.0       140.0    3449
#
#                            acceleration  model_year  origin_europe  \
# name
# chevrolet chevelle malibu          12.0          70              0
# buick skylark 320                  11.5          70              0
# plymouth satellite                 11.0          70              0
# amc rebel sst                      12.0          70              0
# ford torino                        10.5          70              0
#
#                            origin_japan  origin_usa
# name
# chevrolet chevelle malibu             0           1
# buick skylark 320                     0           1
# plymouth satellite                    0           1
# amc rebel sst                         0           1
# ford torino                           0           1

# %%
dfnorm.head()
# Out:
#                                 mpg  cylinders  displacement  horsepower  \
# name
# chevrolet chevelle malibu -0.706439   1.498191      1.090604    0.664133
# buick skylark 320         -1.090751   1.498191      1.503514    1.574594
# plymouth satellite        -0.706439   1.498191      1.196232    1.184397
# amc rebel sst             -0.962647   1.498191      1.061796    1.184397
# ford torino               -0.834543   1.498191      1.042591    0.924265
#
#                              weight  acceleration  model_year  origin_europe  \
# name
# chevrolet chevelle malibu  0.630870     -1.295498   -1.627426      -0.461968
# buick skylark 320          0.854333     -1.477038   -1.627426      -0.461968
# plymouth satellite         0.550470     -1.658577   -1.627426      -0.461968
# amc rebel sst              0.546923     -1.295498   -1.627426      -0.461968
# ford torino                0.565841     -1.840117   -1.627426      -0.461968
#
#                            origin_japan  origin_usa
# name
# chevrolet chevelle malibu     -0.497643    0.773559
# buick skylark 320             -0.497643    0.773559
# plymouth satellite            -0.497643    0.773559
# amc rebel sst                 -0.497643    0.773559
# ford torino                   -0.497643    0.773559

# %%
colpca = [f'PC{i+1}' for i in range(10)]
dfpca = pd.DataFrame(datospca, index=df.index, columns=colpca)
dfpca
# Out:
#                                 PC1       PC2       PC3       PC4       PC5  \
# name
# chevrolet chevelle malibu  2.802397  0.293560  0.664603  0.512668 -0.742620
# buick skylark 320          3.586042  0.329966  0.976832  0.279768 -0.592311
# plymouth satellite         3.100857  0.270273  0.952539  0.244860 -0.966874
# amc rebel sst              3.049826  0.335235  0.803286  0.485423 -0.714364
# ford torino                3.038119  0.284277  0.976454  0.265211 -1.104006
# ...                             ...       ...       ...       ...       ...
# ford mustang gl           -0.882990 -0.944062 -1.466529 -0.760562 -0.603994
# vw pickup                 -4.335065  1.336604 -2.068341 -0.847935  1.893969
# dodge rampage             -1.024520 -1.126728 -0.846054 -1.486058 -1.903992
# ford ranger               -1.420502 -0.895046 -1.995577 -0.235673 -0.024492
# chevy s-10                -1.564204 -0.934315 -2.131757 -0.234625  0.158576
#
#                                 PC6       PC7       PC8       PC9  \
# name
# chevrolet chevelle malibu  0.769629 -0.473689 -0.098276 -0.121285
# buick skylark 320          0.496867  0.006097  0.214176  0.073795
# plymouth satellite         0.737947 -0.217786  0.142058 -0.084772
# amc rebel sst              0.542858 -0.236209  0.291442 -0.148861
# ford torino                0.594251 -0.475743 -0.004610 -0.175613
# ...                             ...       ...       ...       ...
# ford mustang gl           -0.636232  0.188404 -0.163972  0.018396
# vw pickup                  1.363716  0.647313  0.287660  0.111622
# dodge rampage             -0.243112 -0.043176 -0.220778  0.048461
# ford ranger               -0.452349  0.303341  0.117645 -0.027092
# chevy s-10                -0.157749  0.583883  0.070190 -0.121253
#
#                                    PC10
# name
# chevrolet chevelle malibu -5.641092e-17
# buick skylark 320         -5.641092e-17
# plymouth satellite         5.461138e-17
# amc rebel sst              5.461138e-17
# ford torino                5.461138e-17
# ...                                 ...
# ford mustang gl           -1.674332e-16
# vw pickup                  5.884890e-16
# dodge rampage              5.461138e-17
# ford ranger               -5.641092e-17
# chevy s-10                 5.461138e-17
#
# [392 rows x 10 columns]

# %% [markdown]
# ## Visualize Components & Clusters

# %% [markdown]
# > - A **scatterplot** with `PC1` & `PC2`
# > - Colour points by `cluster`
# > - Are they **mixed** now?

# %%
sns.scatterplot(data= dfpca, x='PC1', y='PC2',hue= dfsel['cluster']);

# %% [markdown]
# ## Relationship between Original Variables & Components

# %% [markdown]
# ### Loading Vectors

# %%
df.head()
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0       130.0    3504
# buick skylark 320          15.0          8         350.0       165.0    3693
# plymouth satellite         18.0          8         318.0       150.0    3436
# amc rebel sst              16.0          8         304.0       150.0    3433
# ford torino                17.0          8         302.0       140.0    3449
#
#                            acceleration  model_year  origin_europe  \
# name
# chevrolet chevelle malibu          12.0          70              0
# buick skylark 320                  11.5          70              0
# plymouth satellite                 11.0          70              0
# amc rebel sst                      12.0          70              0
# ford torino                        10.5          70              0
#
#                            origin_japan  origin_usa
# name
# chevrolet chevelle malibu             0           1
# buick skylark 320                     0           1
# plymouth satellite                    0           1
# amc rebel sst                         0           1
# ford torino                           0           1

# %%
dfnorm.head()
# Out:
#                                 mpg  cylinders  displacement  horsepower  \
# name
# chevrolet chevelle malibu -0.706439   1.498191      1.090604    0.664133
# buick skylark 320         -1.090751   1.498191      1.503514    1.574594
# plymouth satellite        -0.706439   1.498191      1.196232    1.184397
# amc rebel sst             -0.962647   1.498191      1.061796    1.184397
# ford torino               -0.834543   1.498191      1.042591    0.924265
#
#                              weight  acceleration  model_year  origin_europe  \
# name
# chevrolet chevelle malibu  0.630870     -1.295498   -1.627426      -0.461968
# buick skylark 320          0.854333     -1.477038   -1.627426      -0.461968
# plymouth satellite         0.550470     -1.658577   -1.627426      -0.461968
# amc rebel sst              0.546923     -1.295498   -1.627426      -0.461968
# ford torino                0.565841     -1.840117   -1.627426      -0.461968
#
#                            origin_japan  origin_usa
# name
# chevrolet chevelle malibu     -0.497643    0.773559
# buick skylark 320             -0.497643    0.773559
# plymouth satellite            -0.497643    0.773559
# amc rebel sst                 -0.497643    0.773559
# ford torino                   -0.497643    0.773559

# %%
dfpca.head()
# Out:
#                                 PC1       PC2       PC3       PC4       PC5  \
# name
# chevrolet chevelle malibu  2.802397  0.293560  0.664603  0.512668 -0.742620
# buick skylark 320          3.586042  0.329966  0.976832  0.279768 -0.592311
# plymouth satellite         3.100857  0.270273  0.952539  0.244860 -0.966874
# amc rebel sst              3.049826  0.335235  0.803286  0.485423 -0.714364
# ford torino                3.038119  0.284277  0.976454  0.265211 -1.104006
#
#                                 PC6       PC7       PC8       PC9  \
# name
# chevrolet chevelle malibu  0.769629 -0.473689 -0.098276 -0.121285
# buick skylark 320          0.496867  0.006097  0.214176  0.073795
# plymouth satellite         0.737947 -0.217786  0.142058 -0.084772
# amc rebel sst              0.542858 -0.236209  0.291442 -0.148861
# ford torino                0.594251 -0.475743 -0.004610 -0.175613
#
#                                    PC10
# name
# chevrolet chevelle malibu -5.641092e-17
# buick skylark 320         -5.641092e-17
# plymouth satellite         5.461138e-17
# amc rebel sst              5.461138e-17
# ford torino                5.461138e-17

# %%
loadings = pd.DataFrame(pca.components_, columns=df.columns, index=colpca).T
loadings
# Out:
#                     PC1       PC2       PC3       PC4       PC5       PC6  \
# mpg           -0.367106 -0.150109 -0.054341 -0.259149 -0.147167  0.747806
# cylinders      0.387568 -0.045398  0.020061 -0.105908  0.252445  0.479917
# displacement   0.402415 -0.041913  0.014231 -0.103237  0.178485  0.300361
# horsepower     0.379338  0.005149  0.234369 -0.203496  0.056066 -0.070476
# weight         0.385829  0.007985 -0.038550 -0.110274  0.398785 -0.120822
# acceleration  -0.246830  0.057556 -0.444529  0.440393  0.661602  0.100407
# model_year    -0.191344 -0.400459 -0.363659 -0.705053  0.223106 -0.298608
# origin_europe -0.159440  0.748044  0.035360 -0.348446  0.137020  0.015211
# origin_japan  -0.214527 -0.450855  0.588295  0.123833  0.298530 -0.031693
# origin_usa     0.302233 -0.216884 -0.512671  0.172053 -0.353829  0.014154
#
#                     PC7       PC8       PC9          PC10
# mpg            0.370230 -0.195897 -0.127560  2.505879e-16
# cylinders     -0.544162  0.309366 -0.387612  3.832174e-16
# displacement   0.000420 -0.116868  0.830490 -2.753318e-16
# horsepower     0.673184  0.531831 -0.124922  1.810120e-16
# weight         0.213058 -0.708413 -0.341403 -8.145988e-17
# acceleration   0.212751  0.223007  0.037640  1.734009e-17
# model_year    -0.114799  0.129361  0.069403  4.717652e-17
# origin_europe -0.048405  0.015417  0.038333  5.189293e-01
# origin_japan  -0.043995 -0.027431  0.029974  5.436647e-01
# origin_usa     0.074338  0.010480 -0.054859  6.596523e-01

# %% [markdown]
# ### Calculating One PCA Value

# %%
dfpca.head()
# Out:
#                                 PC1       PC2       PC3       PC4       PC5  \
# name
# chevrolet chevelle malibu  2.802397  0.293560  0.664603  0.512668 -0.742620
# buick skylark 320          3.586042  0.329966  0.976832  0.279768 -0.592311
# plymouth satellite         3.100857  0.270273  0.952539  0.244860 -0.966874
# amc rebel sst              3.049826  0.335235  0.803286  0.485423 -0.714364
# ford torino                3.038119  0.284277  0.976454  0.265211 -1.104006
#
#                                 PC6       PC7       PC8       PC9  \
# name
# chevrolet chevelle malibu  0.769629 -0.473689 -0.098276 -0.121285
# buick skylark 320          0.496867  0.006097  0.214176  0.073795
# plymouth satellite         0.737947 -0.217786  0.142058 -0.084772
# amc rebel sst              0.542858 -0.236209  0.291442 -0.148861
# ford torino                0.594251 -0.475743 -0.004610 -0.175613
#
#                                    PC10
# name
# chevrolet chevelle malibu -5.641092e-17
# buick skylark 320         -5.641092e-17
# plymouth satellite         5.461138e-17
# amc rebel sst              5.461138e-17
# ford torino                5.461138e-17

# %%
dfnorm.iloc[0,:]
# Out:
# mpg             -0.706439
# cylinders        1.498191
# displacement     1.090604
# horsepower       0.664133
# weight           0.630870
# acceleration    -1.295498
# model_year      -1.627426
# origin_europe   -0.461968
# origin_japan    -0.497643
# origin_usa       0.773559
# Name: chevrolet chevelle malibu, dtype: float64

# %%
loadings.PC1
# Out:
# mpg             -0.367106
# cylinders        0.387568
# displacement     0.402415
# horsepower       0.379338
# weight           0.385829
# acceleration    -0.246830
# model_year      -0.191344
# origin_europe   -0.159440
# origin_japan    -0.214527
# origin_usa       0.302233
# Name: PC1, dtype: float64

# %%
mult= dfnorm.iloc[0,:]*loadings.PC1

# %%
mult.sum()
# Out:
# 2.8195774771769613

# %%
dfpca.head()
# Out:
#                                 PC1       PC2       PC3       PC4       PC5  \
# name
# chevrolet chevelle malibu  2.802397  0.293560  0.664603  0.512668 -0.742620
# buick skylark 320          3.586042  0.329966  0.976832  0.279768 -0.592311
# plymouth satellite         3.100857  0.270273  0.952539  0.244860 -0.966874
# amc rebel sst              3.049826  0.335235  0.803286  0.485423 -0.714364
# ford torino                3.038119  0.284277  0.976454  0.265211 -1.104006
#
#                                 PC6       PC7       PC8       PC9  \
# name
# chevrolet chevelle malibu  0.769629 -0.473689 -0.098276 -0.121285
# buick skylark 320          0.496867  0.006097  0.214176  0.073795
# plymouth satellite         0.737947 -0.217786  0.142058 -0.084772
# amc rebel sst              0.542858 -0.236209  0.291442 -0.148861
# ford torino                0.594251 -0.475743 -0.004610 -0.175613
#
#                                    PC10
# name
# chevrolet chevelle malibu -5.641092e-17
# buick skylark 320         -5.641092e-17
# plymouth satellite         5.461138e-17
# amc rebel sst              5.461138e-17
# ford torino                5.461138e-17

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Biplot

# %%
pca.explained_variance_ratio_
# Out:
# array([5.79736421e-01, 1.32145912e-01, 1.18786549e-01, 7.28643499e-02,
#        5.86029679e-02, 1.82296667e-02, 1.12524470e-02, 5.32083203e-03,
#        3.06085481e-03, 4.04341531e-33])

# %%
pca.explained_variance_ratio_.cumsum()
# Out:
# array([0.57973642, 0.71188233, 0.83066888, 0.90353323, 0.9621362 ,
#        0.98036587, 0.99161831, 0.99693915, 1.        , 1.        ])

# %%
pca.explained_variance_ratio_.sum()
# Out:
# 0.9999999999999999

# %% [markdown]
# # Achieved Goals

# %% [markdown]
# _Double click on **this cell** and place an `X` inside the square brackets (i.e., [X]) if you think you understand the goal:_
#
# - [ ] Understand the role of **Linear Algebra** on Machine Learning
#     - Matrix Multiplications with the `loadings`
# - [ ] Necessity to `StandardScaler()` the data when the algorithm implies distance calculations
# - [ ] Understand that every Machine Learning process is a matter of optimization
#     - To find the best numbers based on a criteria
#     - How is done in `PCA()`?
# - [ ] Why would you use PCA?
#     - Visualization
#     - Preprocess the data for modelling
# - [ ] There are techniques for everything
#     - [ ] Grouping observations
#     - [ ] Grouping variables
